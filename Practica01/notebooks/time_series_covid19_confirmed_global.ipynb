# %%
pip install mysql-connector
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
source = create_engine('mysql+mysqlconnector://test:test123@db/test')

# %%
import pandas as pd
pd.read_sql("select current_date", con=source)
# Out:
#   current_date
# 0   2021-02-04

# %%
df = pd.read_csv('time_series_covid19_confirmed_global.csv',  encoding='utf-8')
df
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 266            NaN             Vietnam  14.058324  108.277199        0
# 267            NaN  West Bank and Gaza  31.952200   35.233200        0
# 268            NaN               Yemen  15.552727   48.516388        0
# 269            NaN              Zambia -13.133897   27.849332        0
# 270            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  12/4/20  12/5/20  \
# ...

# %%
#chequeando los tipos de variable
df.dtypes
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# 1/22/20             int64
#                    ...
# 12/9/20             int64
# 12/10/20            int64
# 12/11/20            int64
# 12/12/20            int64
# 12/13/20            int64
# Length: 331, dtype: object

# %%
df
df.drop(columns=['Province/State'])
# Out:
#          Country/Region        Lat        Long  1/22/20  1/23/20  1/24/20  \
# 0           Afghanistan  33.939110   67.709953        0        0        0
# 1               Albania  41.153300   20.168300        0        0        0
# 2               Algeria  28.033900    1.659600        0        0        0
# 3               Andorra  42.506300    1.521800        0        0        0
# 4                Angola -11.202700   17.873900        0        0        0
# ..                  ...        ...         ...      ...      ...      ...
# 266             Vietnam  14.058324  108.277199        0        2        2
# 267  West Bank and Gaza  31.952200   35.233200        0        0        0
# 268               Yemen  15.552727   48.516388        0        0        0
# 269              Zambia -13.133897   27.849332        0        0        0
# 270            Zimbabwe -19.015438   29.154857        0        0        0
#
#      1/25/20  1/26/20  1/27/20  1/28/20  ...  12/4/20  12/5/20  12/6/20  \
# ...

# %%
#df_t = df.T
#df_t

#df.drop('Province/State')
variables = [
    "Province/State",
    "Country/Region",
    "Lat",
    "Long"

]

df_melted = pd.melt(frame=df, id_vars= variables, var_name="fecha",value_name="confirmed")

df_melted.drop(columns=['Province/State'])
# Out:
#            Country/Region        Lat        Long     fecha  confirmed
# 0             Afghanistan  33.939110   67.709953   1/22/20          0
# 1                 Albania  41.153300   20.168300   1/22/20          0
# 2                 Algeria  28.033900    1.659600   1/22/20          0
# 3                 Andorra  42.506300    1.521800   1/22/20          0
# 4                  Angola -11.202700   17.873900   1/22/20          0
# ...                   ...        ...         ...       ...        ...
# 88612             Vietnam  14.058324  108.277199  12/13/20       1397
# 88613  West Bank and Gaza  31.952200   35.233200  12/13/20     109738
# 88614               Yemen  15.552727   48.516388  12/13/20       2083
# 88615              Zambia -13.133897   27.849332  12/13/20      18274
# 88616            Zimbabwe -19.015438   29.154857  12/13/20      11246
#
# [88617 rows x 5 columns]

# %%
x = pd.io.sql.get_schema(df_melted.reset_index(), 'test_time_series_covid', con=source)

print(x)
# Out:
# CREATE TABLE test_time_series_covid (
# 	`index` BIGINT,
# 	`Province/State` TEXT,
# 	`Country/Region` TEXT,
# 	`Lat` FLOAT(53),
# 	`Long` FLOAT(53),
# 	fecha TEXT,
# 	confirmed BIGINT
# )

# %%
with open("./queries/unconfirmed_transactions" , 'w') as f:
    f.write(x)
    f.close()
